# %%
# Open the file in read mode
text = open("/Users/adityashah/Desktop/jupyter/Page1.txt", "r")
# test1 =open("/Users/adityashah/Desktop/jupyter/Page2.txt", "r")
# text2 =open("/Users/adityashah/Desktop/jupyter/Page3.txt", "r")
# Create an empty dictionary
d = dict()

# Loop through each line of the file
for line in text:
	# Remove the leading spaces and newline character
	line = line.strip()

	# Convert the characters in line to
	# lowercase to avoid case mismatch
	line = line.lower()

	# Split the line into words
	words = line.split(" ")

	# Iterate over each word in line
	for word in words:
		# Check if the word is already in dictionary
		if word in d:
			# Increment count of word by 1
			d[word] = d[word] + 1
		else:
			# Add the word to dictionary with count 1
			d[word] = 1

# Print the contents of dictionary
for key in list(d.keys()):
	print(key, ":", d[key])
# Out:
# chapter : 1
# 1 : 1
# introducing : 1
# bedework : 11
# 3.6 : 2
# 1.1 : 1
# system : 3
# overview : 1
# is : 6
# an : 2
# open-source : 1
# enterprise : 1
# calendar : 4
# that : 1
# supports : 1
# public, : 1
# personal, : 1
# and : 11
# group : 2
# calendaring. : 1
# it : 3
# designed : 1
# to : 6
# conform : 1
# current : 1
# calendaring : 4
# standards : 1
# with : 4
# a : 5
# goal : 1
# of : 8
# attaining : 1
# strong : 1
# interoperability : 1
# between : 1
# other : 3
# systems : 1
# clients. : 1
# built : 1
# emphasis : 1
# on : 1
# higher : 1
# education, : 1
# though : 1
# used : 2
# by : 1
# many : 1
# commercial : 1
# enterprises. : 1
# you : 1
# may : 1
# choose : 1
# deploy : 1
# for : 10
# public : 8
# events : 8
# calendaring, : 1
# personal : 3
# scheduling, : 1
# or : 3
# both. : 1
# suitable : 1
# embedding : 1
# in : 5
# applications : 1
# portals : 1
# has : 2
# been : 1
# deployed : 1
# across : 1
# wide : 1
# range : 1
# environments. : 1
# architecture : 2
# ...

# %%
import glob 
import os 
 
file_list = glob.glob(os.path.join(os.getcwd(), "/Users/adityashah/Desktop/jupyter/Test/", "*.txt")) 
 
text = [] 
 
for file_path in file_list: 
    with open(file_path) as f_input: 
        text.append(f_input.read()) 
 
 
d = dict()
for line in text:
    line = line.strip()
    line = line.lower()
    words = line.split(" ")
    for word in words:
        if word in d:
            d[word] = d[word] + 1
        else:
            d[word] = 1

for key in sorted(d.keys()):
    print(key, ":",d[key])
# Out:
# root : 1
# "calendar : 1
# "skinned" : 1
# & : 4
# (and : 2
# (draft)
# vvenue : 1
# (draft)
# •
# caldav : 1
# (rfc2445)
# itip : 1
# (rfc2446)
# caldav : 1
# (rfc4791)
# caldav : 1
# - : 2
# /public : 1
# /user
# personal : 1
# 1 : 1
# 1.5 : 1
# 2010
# go : 2
# 3.6 : 1
# 3.6
# 1.1
# bedework : 1
# 31, : 2
# 4 : 1
# 5.
# features : 1
# : : 11
# a : 18
# about : 1
# access : 3
# across : 1
# add
# and : 1
# admin : 1
# administration : 1
# administrative : 3
# administrators : 2
# administrators.
# personal : 1
# all : 1
# all
# database : 1
# allowing : 4
# an : 2
# and : 30
# and
# clients : 1
# and
# group : 1
# and
# mar : 1
# and
# scheduling, : 1
# and
# uses. : 1
# any : 1
# apple's : 2
# applications : 1
# appropriate. : 1
# architecture : 1
# architecture
# bedework : 1
# are : 10
# are
# publicly : 1
# are
# stored : 1
# as : 2
# authenticated : 2
# authentication : 1
# available : 1
# backup, : 1
# based : 3
# be : 2
# become : 2
# bedework : 13
# bedework
# public : 1
# ...
